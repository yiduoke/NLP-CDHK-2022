# %%
NLP PROJECT PLAYGROUND

# %%
import json

# Opening JSON file
f = open('gg2015.json')
 
# returns JSON object as
# a dictionary
data = json.load(f)

# print first 100 tweets
for tweet in data[:100]:
    print(tweet['text'], data[99]['user']['screen_name'])

f.close()
# Out:
# just had to scramble to find a golden globes stream for my brother. :D
# RT @ENews: Show us how you're watching the #GoldenGlobes -- tweet us a pic of your set up, we'll RT our faves! #ERedCarpet
# @danaKStew @50ShadesWorldcm @ScarletteDrake Also Red Carpet um 12 &amp; die Show vill. um 1?!
# RT @lisarinna: When your husband tells you that you Are going to the #GoldenGlobes parties like 5 minutes before you go.......
# You just gra…
# “@goldenglobes: Creating multiple mini Moët Moments on the @GoldenGlobes red carpet… http://t.co/vaLDYqbuD1
# #MoetMoment” May I have one plz?
# @pattistarz watching dallas game? watching golden globes tonight?
# “@MileyRayKingdom: Cara's attending the Golden Globes today too so if Miley's going they better take a selfie” 😏
# With the #GoldenGlobes tonight, I think I'll live tweet the event, warming up for my yearly #AcademyAward live tweet session.
# @theodoremelfi best of luck old friend #GoldenGlobes #StVincent #writing
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('names.tsv', sep='\t')
df.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0053137,tt0072308,tt0050419,tt0031983
# 1  tt0038355,tt0071877,tt0037382,tt0117057
# 2  tt0057345,tt0054452,tt0056404,tt0049189
# 3  tt0080455,tt0077975,tt0078723,tt0072562
# 4  tt0083922,tt0050986,tt0060827,tt0050976

# %%
df = df.drop(['nconst', 'birthYear', 'primaryProfession', "knownForTitles"], axis='columns')
df.head()
# Out:
#        primaryName deathYear
# 0     Fred Astaire      1987
# 1    Lauren Bacall      2014
# 2  Brigitte Bardot        \N
# 3     John Belushi      1982
# 4   Ingmar Bergman      2007

# %%
df["deathYear"].mask(df["deathYear"]=="\\N", 2020, inplace=True)
#df[df['deathYear']=='\\N'] = 2020

# %%
df = df[df['deathYear'].astype(int) > 2010]

# %%
df.head()
# Out:
#             primaryName deathYear
# 1         Lauren Bacall      2014
# 2       Brigitte Bardot      2020
# 12            Doris Day      2019
# 13  Olivia de Havilland      2020
# 17         Kirk Douglas      2020
